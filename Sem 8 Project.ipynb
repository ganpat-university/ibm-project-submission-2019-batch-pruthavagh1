# %%
import pandas as pd

# %%
df = pd.read_csv("Dataset.csv")

# %%
df
# Out:
#       Area  Days  Height  Width     Type    Price  Unnamed: 6  Unnamed: 7  \
# 0    Ankur  40.0    10.0   14.0   Mobile  60742.0         NaN         NaN
# 1    Ankur  26.0    12.0   12.0  Digital  40676.0         NaN         NaN
# 2    Ankur  23.0    12.0   12.0       2D  51167.0         NaN         NaN
# 3    Ankur  22.0    18.0   11.0       3D  58074.0         NaN         NaN
# 4    Ankur  24.0    13.0   11.0   Mobile  55712.0         NaN         NaN
# ..     ...   ...     ...    ...      ...      ...         ...         ...
# 215    NaN   NaN     NaN    NaN      NaN      NaN         NaN         NaN
# 216    NaN   NaN     NaN    NaN      NaN      NaN         NaN         NaN
# 217    NaN   NaN     NaN    NaN      NaN      NaN         NaN         NaN
# 218    NaN   NaN     NaN    NaN      NaN      NaN         NaN         NaN
# 219    NaN   NaN     NaN    NaN      NaN      NaN         NaN         NaN
#
#      Unnamed: 8
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 215         NaN
# 216         NaN
# 217         NaN
# 218         NaN
# 219         NaN
#
# [220 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Area           21
# Days           21
# Height         21
# Width          21
# Type           21
# Price          21
# Unnamed: 6    220
# Unnamed: 7    220
# Unnamed: 8    220
# dtype: int64

# %%
df=df.drop(['Unnamed: 6','Unnamed: 7','Unnamed: 8'], axis=1)

# %%
df.isnull().sum()
# Out:
# Area      21
# Days      21
# Height    21
# Width     21
# Type      21
# Price     21
# dtype: int64

# %%
df
# Out:
#       Area  Days  Height  Width     Type    Price
# 0    Ankur  40.0    10.0   14.0   Mobile  60742.0
# 1    Ankur  26.0    12.0   12.0  Digital  40676.0
# 2    Ankur  23.0    12.0   12.0       2D  51167.0
# 3    Ankur  22.0    18.0   11.0       3D  58074.0
# 4    Ankur  24.0    13.0   11.0   Mobile  55712.0
# ..     ...   ...     ...    ...      ...      ...
# 215    NaN   NaN     NaN    NaN      NaN      NaN
# 216    NaN   NaN     NaN    NaN      NaN      NaN
# 217    NaN   NaN     NaN    NaN      NaN      NaN
# 218    NaN   NaN     NaN    NaN      NaN      NaN
# 219    NaN   NaN     NaN    NaN      NaN      NaN
#
# [220 rows x 6 columns]

# %%
df.tail(25)
# Out:
#           Area  Days  Height  Width     Type    Price
# 195  Satellite  45.0    22.0   19.0   Mobile  71207.0
# 196  Satellite  38.0    25.0   22.0       2D  41930.0
# 197  Satellite  25.0    27.0   25.0   Square  92621.0
# 198  Satellite  27.0    32.0   14.0  Digital  62293.0
# 199        NaN   NaN     NaN    NaN      NaN      NaN
# 200        NaN   NaN     NaN    NaN      NaN      NaN
# 201        NaN   NaN     NaN    NaN      NaN      NaN
# 202        NaN   NaN     NaN    NaN      NaN      NaN
# 203        NaN   NaN     NaN    NaN      NaN      NaN
# 204        NaN   NaN     NaN    NaN      NaN      NaN
# 205        NaN   NaN     NaN    NaN      NaN      NaN
# 206        NaN   NaN     NaN    NaN      NaN      NaN
# 207        NaN   NaN     NaN    NaN      NaN      NaN
# 208        NaN   NaN     NaN    NaN      NaN      NaN
# 209        NaN   NaN     NaN    NaN      NaN      NaN
# 210        NaN   NaN     NaN    NaN      NaN      NaN
# 211        NaN   NaN     NaN    NaN      NaN      NaN
# 212        NaN   NaN     NaN    NaN      NaN      NaN
# 213        NaN   NaN     NaN    NaN      NaN      NaN
# 214        NaN   NaN     NaN    NaN      NaN      NaN
# 215        NaN   NaN     NaN    NaN      NaN      NaN
# 216        NaN   NaN     NaN    NaN      NaN      NaN
# 217        NaN   NaN     NaN    NaN      NaN      NaN
# 218        NaN   NaN     NaN    NaN      NaN      NaN
# 219        NaN   NaN     NaN    NaN      NaN      NaN

# %%
df = df.dropna()
 
# To reset the indices
df = df.reset_index(drop = True)

# %%
df
# Out:
#           Area  Days  Height  Width     Type    Price
# 0        Ankur  40.0    10.0   14.0   Mobile  60742.0
# 1        Ankur  26.0    12.0   12.0  Digital  40676.0
# 2        Ankur  23.0    12.0   12.0       2D  51167.0
# 3        Ankur  22.0    18.0   11.0       3D  58074.0
# 4        Ankur  24.0    13.0   11.0   Mobile  55712.0
# ..         ...   ...     ...    ...      ...      ...
# 194  Satellite  20.0    19.0   18.0       3D  85444.0
# 195  Satellite  45.0    22.0   19.0   Mobile  71207.0
# 196  Satellite  38.0    25.0   22.0       2D  41930.0
# 197  Satellite  25.0    27.0   25.0   Square  92621.0
# 198  Satellite  27.0    32.0   14.0  Digital  62293.0
#
# [199 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
df['Type'].value_counts()
# Out:
# Mobile     55
# 2D         55
# 3D         33
# Square     22
# Sqaure     22
# Digital    12
# Name: Type, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Science City    39
# Vastrapur       36
# SG Highway      30
# Thaltej         29
# Satellite       26
# Iscon           26
# Ankur           13
# Name: Area, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Area'],df['Price'])
# Out:
# <BarContainer object of 199 artists>

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Type'],df['Price'])
# Out:
# <BarContainer object of 199 artists>
